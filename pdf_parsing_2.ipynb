# %%
from extract_tables_and_images import extract_tables
from IPython.display import display



for i in range(1, 144):
    print(f'page : {i}')
    for d in extract_tables(pdf_path='./data/pdf_1.pdf', page_number=i):
        display(d)
# Out:
# page : 1
# page : 2
# page : 3
# page : 4
# c:\Users\82103\anaconda3\Lib\site-packages\camelot\parsers\lattice.py:397: UserWarning: No tables found on page-4
#   warnings.warn(
# page : 5
# page : 6
# page : 7
# page : 8
# c:\Users\82103\anaconda3\Lib\site-packages\camelot\parsers\lattice.py:397: UserWarning: No tables found on page-8
#   warnings.warn(
# page : 9
# page : 10
# page : 11
# page : 12
# page : 13
# page : 14
# c:\Users\82103\anaconda3\Lib\site-packages\camelot\parsers\lattice.py:397: UserWarning: No tables found on page-14
#   warnings.warn(
# page : 15
# page : 16
#          0                       1
# 0   권고 적용군    고위험군, COPD 환자진료실진료환경
# 1  중재/실행지표               폐활량측정법 시행
# 2     비교지표              폐활량측정법 미시행
# 3      결과물  진단률 향상, 호흡기 합병증 발생률 감소
#                                              0     1          2           3
# 0                                        권고 내용  권고등급       근거수준    권고도출 자료원
# ...
