# %%
from medgenius.extract_tables_and_images import extract_tables
from IPython.display import display



for i in range(1, 144):
    print(f'page : {i}')
    for d in extract_tables(pdf_path='./data/pdf_2.pdf', page_number=i):
        display(d)
# Out:
# page : 1
# c:\Users\82103\anaconda3\Lib\site-packages\camelot\parsers\lattice.py:392: UserWarning: page-1 is image-based, camelot only works on text-based pages.
#   warnings.warn(
# page : 2
# page : 3
# page : 4
# page : 5
# c:\Users\82103\anaconda3\Lib\site-packages\camelot\parsers\lattice.py:397: UserWarning: No tables found on page-4
#   warnings.warn(
# page : 6
# page : 7
# c:\Users\82103\anaconda3\Lib\site-packages\camelot\parsers\lattice.py:397: UserWarning: No tables found on page-6
#   warnings.warn(
# page : 8
# page : 9
# page : 10
# page : 11
# page : 12
# page : 13
# page : 14
# page : 15
# page : 16
# page : 17
# c:\Users\82103\anaconda3\Lib\site-packages\camelot\parsers\lattice.py:397: UserWarning: No tables found on page-16
#   warnings.warn(
# page : 18
# page : 19
# c:\Users\82103\anaconda3\Lib\site-packages\camelot\parsers\lattice.py:397: UserWarning: No tables found on page-18
#   warnings.warn(
#          0                                            1
# ...
